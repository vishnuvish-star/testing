# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x=np.linspace(0,5,11)

# %%
y=x**3

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([  0.   ,   0.125,   1.   ,   3.375,   8.   ,  15.625,  27.   ,
#         42.875,  64.   ,  91.125, 125.   ])

# %%
plt.plot(x,y)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("example")
# Out:
# Text(0.5, 1.0, 'example')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')
plt.subplot(1,2,2)
plt.plot(x,x**2,'b')

# %%
fig=plt.figure()
axis=fig.add_axis([0.1,0.1,.8,.8])
axis.plot(x,y,'g')
axis.set_xlabel('top')
axis.set_ylabel('bottom')
axis.set_title('title')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-5db177b42a52> in <module>
#       1 fig=plt.figure()
# ----> 2 axis=fig.add_axis([0.1,0.1,.8,.8])
#       3 axis.plot(x,y,'g')
#       4 axis.set_xlabel('top')
#       5 axis.set_ylabel('bottom')
#
# AttributeError: 'Figure' object has no attribute 'add_axis'

# %%
fig.axis=plt.subplots()
axis.plot(x,y,'g')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-bc9bedf16514> in <module>
#       1 fig.axis=plt.subplots()
# ----> 2 axis.plot(x,y,'g')
#
# NameError: name 'axis' is not defined

# %%
fig=plt.figure()

axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x , y ,'b')
axes1.set_xlabel('x_label_axes2')
axes1.set_ylabel('y_label_axes2')
axes21.set_title('axes 2 title')

axes2.plot( x , y ,'r')
axes2.set_xlabel('x_label_axes2')
axes2.set_ylabel('y_label_axes2')
axes2.set_title('axes 2 title');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ce5c632544cc> in <module>
#       4 axes2=fig.add_axes([0.2,0.5,0.4,0.3])
#       5
# ----> 6 axes1.plot(x , y ,'b')
#       7 axes1.set_xlabel('x_label_axes2')
#       8 axes1.set_ylabel('y_label_axes2')
#
# NameError: name 'x' is not defined
